# %%
import numpy as np
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns

# Importar bibliotecas para a rede neural
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Carregar os dados processados (se salvos como arquivo .npz)

import os

os.chdir(os.path.dirname(os.getcwd()))
print("diretório:", os.getcwd())


dados = np.load('../dados/dados_processados.npz')

X_train = dados['X_train']
y_train = dados['y_train']
X_val = dados['X_val']
y_val = dados['y_val']
X_test = dados['X_test']
y_test = dados['y_test']
# Out:
# diretório: c:\Users\ianfe\Desktop\IA\projeto_dupla\Atividade-4-Redes-Neurais\notebooks

# %%
# Definindo arquitetura do modelo
model = Sequential([
    Dense(64, input_dim=X_train.shape[1], activation='relu'),
    Dropout(0.5),
    Dense(32, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')  # Saída para classificação binária
])

# Resumo do modelo
model.summary()
# Out:
# c:\Users\ianfe\Desktop\IA\projeto_dupla\Atividade-4-Redes-Neurais\venv\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │           576 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,689 (10.50 KB)
#  Trainable params: 2,689 (10.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compilar o modelo
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# Early Stopping para evitar overfitting
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Treinar o modelo
history = model.fit(X_train, y_train,
                    epochs=100,
                    batch_size=32,
                    validation_data=(X_val, y_val),
                    callbacks=[early_stop],
                    verbose=1)
# Out:
# Epoch 1/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.4544 - loss: 0.7031 - val_accuracy: 0.5105 - val_loss: 0.6939
# Epoch 2/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5196 - loss: 0.6915 - val_accuracy: 0.4895 - val_loss: 0.6930
# Epoch 3/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5150 - loss: 0.6956 - val_accuracy: 0.4965 - val_loss: 0.6927
# Epoch 4/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5164 - loss: 0.6956 - val_accuracy: 0.4895 - val_loss: 0.6926
# Epoch 5/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4798 - loss: 0.6951 - val_accuracy: 0.4895 - val_loss: 0.6919
# Epoch 6/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5116 - loss: 0.6933 - val_accuracy: 0.4476 - val_loss: 0.6912
# Epoch 7/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4755 - loss: 0.6991 - val_accuracy: 0.4615 - val_loss: 0.6907
# Epoch 8/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5012 - loss: 0.6954 - val_accuracy: 0.4825 - val_loss: 0.6903
# Epoch 9/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5104 - loss: 0.6972 - val_accuracy: 0.4895 - val_loss: 0.6907
# Epoch 10/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4944 - loss: 0.6958 - val_accuracy: 0.4615 - val_loss: 0.6903
# Epoch 11/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4912 - loss: 0.6934 - val_accuracy: 0.4755 - val_loss: 0.6895
# Epoch 12/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5518 - loss: 0.6845 - val_accuracy: 0.5245 - val_loss: 0.6883
# Epoch 13/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5423 - loss: 0.6888 - val_accuracy: 0.5734 - val_loss: 0.6886
# Epoch 14/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5132 - loss: 0.6923 - val_accuracy: 0.5594 - val_loss: 0.6886
# Epoch 15/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4823 - loss: 0.6946 - val_accuracy: 0.5035 - val_loss: 0.6891
# Epoch 16/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5482 - loss: 0.6900 - val_accuracy: 0.5245 - val_loss: 0.6883
# Epoch 17/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5259 - loss: 0.6930 - val_accuracy: 0.5175 - val_loss: 0.6881
# Epoch 18/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5703 - loss: 0.6863 - val_accuracy: 0.5175 - val_loss: 0.6880
# Epoch 19/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5100 - loss: 0.6921 - val_accuracy: 0.5524 - val_loss: 0.6884
# Epoch 20/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5415 - loss: 0.6919 - val_accuracy: 0.5524 - val_loss: 0.6880
# Epoch 21/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5796 - loss: 0.6829 - val_accuracy: 0.5245 - val_loss: 0.6873
# Epoch 22/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5426 - loss: 0.6868 - val_accuracy: 0.5175 - val_loss: 0.6870
# Epoch 23/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5668 - loss: 0.6820 - val_accuracy: 0.5175 - val_loss: 0.6872
# Epoch 24/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5293 - loss: 0.6872 - val_accuracy: 0.5734 - val_loss: 0.6869
# Epoch 25/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5218 - loss: 0.6886 - val_accuracy: 0.5035 - val_loss: 0.6870
# Epoch 26/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5728 - loss: 0.6813 - val_accuracy: 0.5315 - val_loss: 0.6871
# Epoch 27/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4992 - loss: 0.6961 - val_accuracy: 0.5175 - val_loss: 0.6873
# Epoch 28/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5058 - loss: 0.6900 - val_accuracy: 0.5245 - val_loss: 0.6878
# Epoch 29/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4915 - loss: 0.6925 - val_accuracy: 0.5315 - val_loss: 0.6892
# Epoch 30/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5480 - loss: 0.6849 - val_accuracy: 0.4895 - val_loss: 0.6877
# Epoch 31/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5289 - loss: 0.6846 - val_accuracy: 0.5664 - val_loss: 0.6873
# Epoch 32/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5476 - loss: 0.6861 - val_accuracy: 0.5524 - val_loss: 0.6873
# Epoch 33/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5466 - loss: 0.6890 - val_accuracy: 0.5594 - val_loss: 0.6872
# Epoch 34/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5550 - loss: 0.6799 - val_accuracy: 0.5734 - val_loss: 0.6869
# Epoch 35/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5540 - loss: 0.6810 - val_accuracy: 0.5455 - val_loss: 0.6855
# Epoch 36/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5020 - loss: 0.6860 - val_accuracy: 0.5524 - val_loss: 0.6864
# Epoch 37/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5533 - loss: 0.6788 - val_accuracy: 0.5385 - val_loss: 0.6873
# Epoch 38/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5708 - loss: 0.6772 - val_accuracy: 0.5804 - val_loss: 0.6884
# Epoch 39/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5571 - loss: 0.6845 - val_accuracy: 0.5455 - val_loss: 0.6880
# Epoch 40/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5225 - loss: 0.6829 - val_accuracy: 0.5594 - val_loss: 0.6878
# Epoch 41/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5576 - loss: 0.6850 - val_accuracy: 0.5315 - val_loss: 0.6891
# Epoch 42/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5465 - loss: 0.6862 - val_accuracy: 0.5175 - val_loss: 0.6885
# Epoch 43/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5742 - loss: 0.6802 - val_accuracy: 0.5664 - val_loss: 0.6864
# Epoch 44/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5487 - loss: 0.6806 - val_accuracy: 0.5245 - val_loss: 0.6866
# Epoch 45/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5669 - loss: 0.6761 - val_accuracy: 0.5455 - val_loss: 0.6871

# %%
# Avaliar o modelo no conjunto de teste
test_loss, test_accuracy = model.evaluate(X_test, y_test, verbose=0)
print(f'Precisão no Teste: {test_accuracy*100:.2f}%')
# Out:
# Precisão no Teste: 55.24%

# %%
# Previsões no conjunto de teste
y_pred_prob = model.predict(X_test)
y_pred = (y_pred_prob >= 0.5).astype(int).flatten()

# Relatório de Classificação
print("Relatório de Classificação:")
print(classification_report(y_test, y_pred))

# Matriz de Confusão
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6,4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Não Popular', 'Popular'], yticklabels=['Não Popular', 'Popular'])
plt.ylabel('Verdadeiro')
plt.xlabel('Predito')
plt.title('Matriz de Confusão')
plt.show()
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Relatório de Classificação:
#               precision    recall  f1-score   support
#
#            0       0.56      0.51      0.54        72
#            1       0.55      0.59      0.57        71
#
#     accuracy                           0.55       143
#    macro avg       0.55      0.55      0.55       143
# weighted avg       0.55      0.55      0.55       143

# %%
# Plotar as curvas de perda
plt.figure(figsize=(12,5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Perda Treino')
plt.plot(history.history['val_loss'], label='Perda Validação')
plt.title('Perda durante o Treinamento')
plt.xlabel('Época')
plt.ylabel('Perda')
plt.legend()

# Plotar as curvas de precisão
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Precisão Treino')
plt.plot(history.history['val_accuracy'], label='Precisão Validação')
plt.title('Precisão durante o Treinamento')
plt.xlabel('Época')
plt.ylabel('Precisão')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Salvar o modelo completo no formato nativo do Keras (.keras)
model.save('../modelos/modelo_spotify.keras')

# %%
# Verificar as formas dos conjuntos de dados
print("Forma de X_train:", X_train.shape)
print("Forma de y_train:", y_train.shape)
print("Forma de X_val:", X_val.shape)
print("Forma de y_val:", y_val.shape)
print("Forma de X_test:", X_test.shape)
print("Forma de y_test:", y_test.shape)
# Out:
# Forma de X_train: (666, 8)
# Forma de y_train: (666,)
# Forma de X_val: (143, 8)
# Forma de y_val: (143,)
# Forma de X_test: (143, 8)
# Forma de y_test: (143,)
